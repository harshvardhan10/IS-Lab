# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.6.0)

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop,SGD

# %% [markdown]
# ### Parameters

# %%
#Specifying the batch_size, classes and epochs
batch_size = 64
num_classes = 10
epochs = 20

# %% [markdown]
# ### Loading data

# %%
#Dividing the datasets into test and train
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train /= 255
x_test /= 255

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_train.shape)
# Out:
# 60000 train samples
# 10000 test samples
# (60000, 784)

# %%
import tensorflow as tf
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling and Training the Model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=SGD(),
              metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=(0.2))
# Out:
# Epoch 1/20
# 750/750 [==============================] - 6s 5ms/step - loss: 0.9832 - accuracy: 0.7416 - val_loss: 0.4134 - val_accuracy: 0.8923
# Epoch 2/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4484 - accuracy: 0.8709 - val_loss: 0.3176 - val_accuracy: 0.9117
# Epoch 3/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3677 - accuracy: 0.8937 - val_loss: 0.2777 - val_accuracy: 0.9220
# Epoch 4/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3244 - accuracy: 0.9066 - val_loss: 0.2523 - val_accuracy: 0.9283
# Epoch 5/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2934 - accuracy: 0.9167 - val_loss: 0.2298 - val_accuracy: 0.9346
# Epoch 6/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2691 - accuracy: 0.9225 - val_loss: 0.2128 - val_accuracy: 0.9398
# Epoch 7/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2493 - accuracy: 0.9280 - val_loss: 0.1999 - val_accuracy: 0.9423
# Epoch 8/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2304 - accuracy: 0.9333 - val_loss: 0.1865 - val_accuracy: 0.9474
# Epoch 9/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2146 - accuracy: 0.9375 - val_loss: 0.1764 - val_accuracy: 0.9507
# Epoch 10/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2019 - accuracy: 0.9416 - val_loss: 0.1669 - val_accuracy: 0.9538
# Epoch 11/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1893 - accuracy: 0.9458 - val_loss: 0.1583 - val_accuracy: 0.9561
# Epoch 12/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1804 - accuracy: 0.9477 - val_loss: 0.1525 - val_accuracy: 0.9572
# Epoch 13/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1731 - accuracy: 0.9493 - val_loss: 0.1473 - val_accuracy: 0.9586
# Epoch 14/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1626 - accuracy: 0.9526 - val_loss: 0.1407 - val_accuracy: 0.9613
# Epoch 15/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1551 - accuracy: 0.9553 - val_loss: 0.1362 - val_accuracy: 0.9623
# Epoch 16/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1495 - accuracy: 0.9574 - val_loss: 0.1310 - val_accuracy: 0.9632
# Epoch 17/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1444 - accuracy: 0.9580 - val_loss: 0.1265 - val_accuracy: 0.9643
# Epoch 18/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1375 - accuracy: 0.9600 - val_loss: 0.1226 - val_accuracy: 0.9644
# Epoch 19/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1314 - accuracy: 0.9616 - val_loss: 0.1202 - val_accuracy: 0.9655
# Epoch 20/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1267 - accuracy: 0.9636 - val_loss: 0.1162 - val_accuracy: 0.9671

# %% [markdown]
# ### Evaluate

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.11175667494535446
# Test accuracy: 0.9656999707221985
